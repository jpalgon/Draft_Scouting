# %% [markdown]
# # Modeling

# %% [markdown]
# ### Import Relevant Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore", category = DeprecationWarning)
warnings.filterwarnings("ignore", category = FutureWarning)
warnings.filterwarnings("ignore", category = UserWarning)

import nltk
from nltk.tokenize import word_tokenize, sent_tokenize, regexp_tokenize, RegexpTokenizer
from nltk.stem import PorterStemmer, snowball
from nltk.corpus import stopwords
from nltk import FreqDist
from wordcloud import WordCloud
from nltk.stem.wordnet import WordNetLemmatizer 
from nltk.corpus import wordnet
from nltk import pos_tag
from nltk.util import ngrams
from nltk.collocations import BigramAssocMeasures, BigramCollocationFinder 
from nltk.util import ngrams

nltk.download('stopwords')

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier, GradientBoostingClassifier
from imblearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeClassifier
from imblearn.over_sampling import SMOTE, RandomOverSampler
from sklearn.preprocessing import LabelEncoder, StandardScaler, OneHotEncoder
from sklearn.metrics import plot_confusion_matrix, classification_report
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\capta\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Read in Processed Data

# %%
df = pd.read_parquet('./Data/processed_reports.parquet')

# %%
df.reset_index(inplace=True)

# %%
df.drop(['index'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4209 entries, 0 to 4208
# Data columns (total 99 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   player                       4209 non-null   object
#  1   report                       4209 non-null   object
#  2   year                         4209 non-null   float64
#  3   weight_x                     3986 non-null   float64
#  4   height_x                     3986 non-null   float64
#  5   pos_rk                       3871 non-null   float64
#  6   ovr_rk                       3292 non-null   float64
#  7   grade                        3877 non-null   float64
#  8   age                          3897 non-null   float64
#  9   Round                        4209 non-null   Int64
#  10  Pick                         4209 non-null   Int64
#  11  target                       4209 non-null   Int64
#  12  processed_report             4209 non-null   object
#  13  reportlen                    4209 non-null   int64
#  14  joined_report                4209 non-null   object
#  15  height_y                     3510 non-null   float64
#  16  weight_y                     3511 non-null   float64
#  17  forty_yd                     3280 non-null   float64
#  18  vertical                     2831 non-null   float64
#  19  bench_reps                   2458 non-null   float64
#  20  broad_jump                   2776 non-null   float64
#  21  cone                         2256 non-null   float64
#  22  shuttle                      2315 non-null   float64
#  23  g_season                     2598 non-null   float64
#  24  def_int_season               818 non-null    float64
#  25  def_int_yds_season           653 non-null    float64
#  26  def_int_yds_per_int_season   651 non-null    float64
#  27  def_int_career               1092 non-null   float64
#  28  def_int_yds_career           974 non-null    float64
#  29  def_int_yds_per_int_career   973 non-null    float64
#  30  pass_cmp_season              172 non-null    float64
#  31  pass_att_season              172 non-null    float64
#  32  pass_cmp_pct_season          172 non-null    float64
#  33  pass_yds_season              172 non-null    float64
#  34  pass_yds_per_att_season      172 non-null    float64
#  35  adj_pass_yds_per_att_season  172 non-null    float64
#  36  pass_td_season               171 non-null    float64
#  37  pass_int_season              170 non-null    float64
#  38  pass_rating_season           172 non-null    float64
#  39  pass_cmp_career              174 non-null    float64
#  40  pass_att_career              174 non-null    float64
#  41  pass_cmp_pct_career          174 non-null    float64
#  42  pass_yds_career              174 non-null    float64
#  43  pass_yds_per_att_career      174 non-null    float64
#  44  adj_pass_yds_per_att_career  174 non-null    float64
#  45  pass_td_career               174 non-null    float64
#  46  pass_int_career              174 non-null    float64
#  47  pass_rating_career           174 non-null    float64
#  48  rush_att_season              631 non-null    float64
#  49  rush_yds_season              626 non-null    float64
#  50  rush_yds_per_att_season      622 non-null    float64
#  51  rush_td_season               386 non-null    float64
#  52  rec_season                   898 non-null    float64
#  53  rec_yds_season               898 non-null    float64
#  54  rec_yds_per_rec_season       898 non-null    float64
#  55  scrim_att_season             903 non-null    float64
#  56  scrim_yds_season             902 non-null    float64
#  57  scrim_yds_per_att_season     902 non-null    float64
#  58  scrim_td_season              878 non-null    float64
#  59  rush_att_career              717 non-null    float64
#  60  rush_yds_career              713 non-null    float64
#  61  rush_yds_per_att_career      710 non-null    float64
#  62  rush_td_career               478 non-null    float64
#  63  rec_career                   909 non-null    float64
#  64  rec_yds_career               909 non-null    float64
#  65  rec_yds_per_rec_career       909 non-null    float64
#  66  rec_td_career                864 non-null    float64
#  67  scrim_att_career             911 non-null    float64
#  68  scrim_yds_career             910 non-null    float64
#  69  scrim_yds_per_att_career     910 non-null    float64
#  70  scrim_td_career              906 non-null    float64
#  71  fumbles_rec_yds_career       205 non-null    float64
#  72  fumbles_rec_td_career        245 non-null    float64
#  73  rec_td_season                768 non-null    float64
#  74  def_int_td_season            202 non-null    float64
#  75  def_int_td_career            423 non-null    float64
#  76  fumbles_rec_career           706 non-null    float64
#  77  fumbles_rec_yds_season       91 non-null     float64
#  78  fumbles_rec_td_season        106 non-null    float64
#  79  fumbles_rec_season           411 non-null    float64
#  80  tackles_solo_season          1494 non-null   float64
#  81  tackles_assists_season       1492 non-null   float64
#  82  tackles_total_season         1498 non-null   float64
#  83  tackles_loss_season          1433 non-null   float64
#  84  sacks_season                 1091 non-null   float64
#  85  pass_defended_season         943 non-null    float64
#  86  tackles_solo_career          1509 non-null   float64
#  87  tackles_assists_career       1511 non-null   float64
#  88  tackles_total_career         1511 non-null   float64
#  89  tackles_loss_career          1496 non-null   float64
#  90  sacks_career                 1275 non-null   float64
#  91  pass_defended_career         1194 non-null   float64
#  92  fumbles_forced_season        648 non-null    float64
#  93  fumbles_forced_career        1006 non-null   float64
#  94  college_conference           2376 non-null   object
#  95  speed                        3273 non-null   float64
#  96  shuttle_agility              2310 non-null   float64
#  97  cone_agility                 2252 non-null   float64
#  98  pos                          4209 non-null   object
# dtypes: Int64(3), float64(89), int64(1), object(6)
# memory usage: 3.2+ MB

# %%
df['target'] = df.Round

# %%
df.target[df.target >= 6] = 0

# %%
df.target[df.target == 1] = 10

# %%
df.target[(df.target == 4) | (df.target == 5)] = 1

# %%
df.target[df.target == 3] = 2

# %%
df.target[df.target == 10] = 3

# %%
cleaned_df = df.drop(['report','processed_report','joined_report','weight_y','height_y'],axis=1)

# %%
cleaned_df = cleaned_df.add_suffix('_col')

# %%
cleaned_df
# Out:
#             player_col  year_col  weight_x_col  height_x_col  pos_rk_col  \
# 0           Alex Smith    2005.0         217.0        76.125         2.0
# 1         Ronnie Brown    2005.0         233.0        72.250         1.0
# 2      Braylon Edwards    2005.0         211.0        74.875         1.0
# 3        Cedric Benson    2005.0         222.0        70.500         3.0
# 4     Carnell Williams    2005.0         217.0        70.875         2.0
# ...                ...       ...           ...           ...         ...
# 4204       Jeff Gunter    2022.0           NaN           NaN         NaN
# 4205      Trenton Gill    2022.0           NaN           NaN         NaN
# 4206      Jesse Luketa    2022.0           NaN           NaN         NaN
# 4207     Marquis Hayes    2022.0           NaN           NaN         NaN
# 4208       Brock Purdy    2022.0           NaN           NaN         NaN
#
#       ovr_rk_col  grade_col  age_col  Round_col  Pick_col  ...  \
# 0            3.0       98.0     21.0          1         1  ...
# 1            4.0       98.0     23.0          1         2  ...
# 2            1.0       99.0     22.0          1         3  ...
# 3           10.0       96.0     22.0          1         4  ...
# 4            6.0       97.0      NaN          1         5  ...
# ...          ...        ...      ...        ...       ...  ...
# 4204         NaN        NaN     23.0          7       252  ...
# 4205         NaN        NaN     23.0          7       255  ...
# 4206         NaN        NaN     23.0          7       256  ...
# 4207         NaN        NaN     23.0          7       257  ...
# 4208         NaN        NaN     22.0          7       262  ...
#
#       tackles_loss_career_col  sacks_career_col  pass_defended_career_col  \
# 0                         NaN               NaN                       NaN
# 1                         NaN               NaN                       NaN
# 2                         NaN               NaN                       NaN
# 3                         NaN               NaN                       NaN
# 4                         NaN               NaN                       NaN
# ...                       ...               ...                       ...
# 4204                     38.5              17.0                       4.0
# 4205                      NaN               NaN                       NaN
# 4206                     11.5               0.5                       6.0
# 4207                      NaN               NaN                       NaN
# 4208                      NaN               NaN                       NaN
#
#       fumbles_forced_season_col  fumbles_forced_career_col  \
# 0                           NaN                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           NaN                        NaN
# 4                           NaN                        NaN
# ...                         ...                        ...
# 4204                        2.0                        9.0
# 4205                        NaN                        NaN
# 4206                        NaN                        NaN
# 4207                        NaN                        NaN
# 4208                        NaN                        NaN
#
#          college_conference_col   speed_col  shuttle_agility_col  \
# 0      Mountain West Conference   88.187311           176.485482
# 1                          None  120.996000           168.168738
# 2                          None  107.614900                  NaN
# 3                          None   97.457455                  NaN
# 4                          None         NaN                  NaN
# ...                         ...         ...                  ...
# 4204        Sun Belt Conference  105.744617           144.109521
# 4205  Atlantic Coast Conference         NaN                  NaN
# 4206         Big Ten Conference   88.494256                  NaN
# 4207      Big Twelve Conference   80.603451                  NaN
# 4208      Big Twelve Conference   77.265285           108.124923
#
#       cone_agility_col  pos_col
# 0           136.815911       QB
# 1           130.199966       RB
# 2                  NaN       WR
# 3                  NaN       RB
# 4                  NaN       RB
# ...                ...      ...
# 4204        137.671457       LB
# 4205               NaN        P
# 4206               NaN       LB
# 4207               NaN       OL
# 4208        113.125383       QB
#
# [4209 rows x 94 columns]

# %%
tf = TfidfVectorizer(ngram_range=(1,3),min_df=.025,max_df =.75)

# %%
X = tf.fit_transform(df.joined_report)

# %%
report_df = pd.DataFrame(X.toarray(),columns=tf.get_feature_names())

# %%
report_df.columns
# Out:
# Index(['2001', '2002', '2003', '2004', '2005', '2006', '2006 draft', '2007',
#        '2014', '2015',
#        ...
#        'work ethic', 'worth', 'would', 'yard', 'yard averag', 'yard per',
#        'yard touchdown', 'year', 'year starter', 'zone'],
#       dtype='object', length=519)

# %%
model_df = pd.concat([cleaned_df,report_df],axis=1)

# %%
model_df
# Out:
#             player_col  year_col  weight_x_col  height_x_col  pos_rk_col  \
# 0           Alex Smith    2005.0         217.0        76.125         2.0
# 1         Ronnie Brown    2005.0         233.0        72.250         1.0
# 2      Braylon Edwards    2005.0         211.0        74.875         1.0
# 3        Cedric Benson    2005.0         222.0        70.500         3.0
# 4     Carnell Williams    2005.0         217.0        70.875         2.0
# ...                ...       ...           ...           ...         ...
# 4204       Jeff Gunter    2022.0           NaN           NaN         NaN
# 4205      Trenton Gill    2022.0           NaN           NaN         NaN
# 4206      Jesse Luketa    2022.0           NaN           NaN         NaN
# 4207     Marquis Hayes    2022.0           NaN           NaN         NaN
# 4208       Brock Purdy    2022.0           NaN           NaN         NaN
#
#       ovr_rk_col  grade_col  age_col  Round_col  Pick_col  ...  work ethic  \
# 0            3.0       98.0     21.0          1         1  ...         0.0
# 1            4.0       98.0     23.0          1         2  ...         0.0
# 2            1.0       99.0     22.0          1         3  ...         0.0
# 3           10.0       96.0     22.0          1         4  ...         0.0
# 4            6.0       97.0      NaN          1         5  ...         0.0
# ...          ...        ...      ...        ...       ...  ...         ...
# 4204         NaN        NaN     23.0          7       252  ...         0.0
# 4205         NaN        NaN     23.0          7       255  ...         0.0
# 4206         NaN        NaN     23.0          7       256  ...         0.0
# 4207         NaN        NaN     23.0          7       257  ...         0.0
# 4208         NaN        NaN     22.0          7       262  ...         0.0
#
#          worth    would      yard  yard averag  yard per  yard touchdown  \
# 0     0.000000  0.09886  0.242642          0.0       0.0        0.097897
# 1     0.000000  0.00000  0.246404          0.0       0.0        0.000000
# 2     0.145143  0.00000  0.185974          0.0       0.0        0.300135
# 3     0.000000  0.00000  0.150002          0.0       0.0        0.121040
# 4     0.000000  0.00000  0.221221          0.0       0.0        0.000000
# ...        ...      ...       ...          ...       ...             ...
# 4204  0.000000  0.00000  0.000000          0.0       0.0        0.000000
# 4205  0.000000  0.00000  0.145878          0.0       0.0        0.000000
# 4206  0.000000  0.00000  0.000000          0.0       0.0        0.000000
# 4207  0.000000  0.00000  0.000000          0.0       0.0        0.000000
# 4208  0.000000  0.00000  0.310415          0.0       0.0        0.000000
#
#           year  year starter      zone
# 0     0.158687           0.0  0.000000
# 1     0.000000           0.0  0.000000
# 2     0.081084           0.0  0.000000
# 3     0.000000           0.0  0.000000
# 4     0.048226           0.0  0.000000
# ...        ...           ...       ...
# 4204  0.000000           0.0  0.000000
# 4205  0.000000           0.0  0.000000
# 4206  0.000000           0.0  0.000000
# 4207  0.000000           0.0  0.144852
# 4208  0.000000           0.0  0.000000
#
# [4209 rows x 613 columns]

# %%
X = model_df.drop(['target_col'],axis=1)
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(model_df.target_col)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.33,random_state=42)

player_name = X_test.player_col
player_year = X_test.year_col
player_pick = X_test.Pick_col
player_target = X_test.Round_col

X_train.drop(['player_col','year_col','Pick_col','Round_col'],axis=1,inplace=True)
X_test.drop(['player_col','year_col','Pick_col','Round_col'],axis=1,inplace=True)

num_cols = X_train.select_dtypes(['Int64','float64'])
cat_cols = X_train.select_dtypes('object')

num_transformer = Pipeline(steps=[('ss',StandardScaler()),
                             ('impute',SimpleImputer(strategy='constant'))])

cat_transformer = Pipeline(steps=[('ohe',OneHotEncoder(drop='first',sparse=False,handle_unknown='ignore'))])

transformer = ColumnTransformer(transformers=[
    ('num',num_transformer,num_cols.columns),
    ('cat',cat_transformer,cat_cols.columns)
])

pipe = Pipeline([
    ('transformer',transformer),
    ('sample',None),
    ('forest',RandomForestClassifier(random_state=42))
])

grid = {
    'sample':[RandomOverSampler(random_state=42),SMOTE(random_state=42)],
    'forest__n_estimators':[85,80,90],
    'forest__criterion':['gini','entropy'],
    'forest__max_depth':[5,22,None],
    'forest__min_samples_split':[1,2],
    'forest__min_samples_leaf':[1,2,3]
}

forest = GridSearchCV(estimator=pipe,
                          param_grid=grid,
                          cv=5)

# %%
forest.best_params_
# Out:
# {'forest__criterion': 'gini',
#  'forest__max_depth': None,
#  'forest__min_samples_leaf': 1,
#  'forest__min_samples_split': 2,
#  'forest__n_estimators': 85,
#  'sample': RandomOverSampler(random_state=42)}

# %%
forest.fit(X_train,y_train)
y_pred = forest.predict(X_test)
print(classification_report(y_test,y_pred))
plot_confusion_matrix(forest,X_test,y_test);
# Out:
# C:\Users\capta\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 540 fits failed out of a total of 1080.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 540 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\capta\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\capta\anaconda3\lib\site-packages\imblearn\pipeline.py", line 297, in fit
#     self._final_estimator.fit(Xt, yt, **fit_params_last_step)
#   File "C:\Users\capta\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 450, in fit
#     trees = Parallel(
#   File "C:\Users\capta\anaconda3\lib\site-packages\joblib\parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\capta\anaconda3\lib\site-packages\joblib\parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\capta\anaconda3\lib\site-packages\joblib\parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#   File "C:\Users\capta\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#   File "C:\Users\capta\anaconda3\lib\site-packages\joblib\_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#   File "C:\Users\capta\anaconda3\lib\site-packages\joblib\parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#   File "C:\Users\capta\anaconda3\lib\site-packages\joblib\parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#   File "C:\Users\capta\anaconda3\lib\site-packages\sklearn\utils\fixes.py", line 216, in __call__
#     return self.function(*args, **kwargs)
#   File "C:\Users\capta\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 185, in _parallel_build_trees
#     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#   File "C:\Users\capta\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 937, in fit
#     super().fit(
#   File "C:\Users\capta\anaconda3\lib\site-packages\sklearn\tree\_classes.py", line 250, in fit
#     raise ValueError(
# ValueError: min_samples_split must be an integer greater than 1 or a float in (0.0, 1.0]; got the integer 1
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
#               precision    recall  f1-score   support
#
#            0       0.59      0.66      0.62       375
#            1       0.48      0.44      0.46       407
#            2       0.63      0.61      0.62       420
#            3       0.73      0.74      0.73       187
#
#     accuracy                           0.59      1389
#    macro avg       0.61      0.61      0.61      1389
# weighted avg       0.59      0.59      0.59      1389

# %%
X = model_df.drop(['target_col'],axis=1)
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(model_df.target_col)

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.33,random_state=42)

player_name = X_test.player_col
player_year = X_test.year_col
player_pick = X_test.Pick_col
player_round = X_test.Round_col

X_train.drop(['player_col','year_col','Pick_col','Round_col'],axis=1,inplace=True)
X_test.drop(['player_col','year_col','Pick_col','Round_col'],axis=1,inplace=True)

num_cols = X_train.select_dtypes(['Int64','float64'])
cat_cols = X_train.select_dtypes('object')

num_transformer = Pipeline(steps=[('ss',StandardScaler()),
                             ('impute',SimpleImputer(strategy='constant'))])

cat_transformer = Pipeline(steps=[('ohe',OneHotEncoder(drop='first',sparse=False,handle_unknown='ignore'))])

transformer = ColumnTransformer(transformers=[
    ('num',num_transformer,num_cols.columns),
    ('cat',cat_transformer,cat_cols.columns)
])

pipe = Pipeline([
    ('transformer',transformer),
    ('sample',None),
    ('gbc',GradientBoostingClassifier(random_state=42))
])

grid = {
    'sample':[RandomOverSampler(random_state=42),SMOTE(random_state=42)],
    'gbc__n_estimators':[75,100,115],
    'gbc__criterion':['friedman_mse', 'squared_error'],
    'gbc__max_depth':[4,22,None],
    'gbc__min_samples_split':[1,2],
    'gbc__min_samples_leaf':[1,2,3],
    'gbc__learning_rate':[.01,.1,1]
}

gbc = GridSearchCV(estimator=pipe,
                          param_grid=grid,
                          cv=5)

# %%
gbc.fit(X_train,y_train)
y_pred = gbc.predict(X_test)
print(classification_report(y_test,y_pred))
plot_confusion_matrix(gbc,X_test,y_test);
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5000\3899331081.py in <module>
# ----> 1 gbc.fit(X_train,y_train)
#       2 y_pred = gbc.predict(X_test)
#       3 print(classification_report(y_test,y_pred))
#       4 plot_confusion_matrix(gbc,X_test,y_test);
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     889                 return results
#     890
# --> 891             self._run_search(evaluate_candidates)
#     892
#     893             # multimetric is determined here because in the case of a callable
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1390     def _run_search(self, evaluate_candidates):
#    1391         """Search all candidates in param_grid"""
# -> 1392         evaluate_candidates(ParameterGrid(self.param_grid))
#    1393
#    1394
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     836                     )
#     837
# --> 838                 out = parallel(
#     839                     delayed(_fit_and_score)(
#     840                         clone(base_estimator),
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1086                 self._iterating = self._original_iterator is not None
#    1087
# -> 1088             while self.dispatch_one_batch(iterator):
#    1089                 pass
#    1090
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     899                 return False
#     900             else:
# --> 901                 self._dispatch(tasks)
#     902                 return True
#     903
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     817         with self._lock:
#     818             job_idx = len(self._jobs)
# --> 819             job = self._backend.apply_async(batch, callback=cb)
#     820             # A job can complete so quickly than its callback is
#     821             # called before we get here, causing self._jobs to
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     595         # Don't delay the application, to avoid keeping the input
#     596         # arguments in memory
# --> 597         self.results = batch()
#     598
#     599     def get(self):
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     286         # change the default number of processes to -1
#     287         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288             return [func(*args, **kwargs)
#     289                     for func, args, kwargs in self.items]
#     290
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     286         # change the default number of processes to -1
#     287         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288             return [func(*args, **kwargs)
#     289                     for func, args, kwargs in self.items]
#     290
#
# ~\anaconda3\lib\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     214     def __call__(self, *args, **kwargs):
#     215         with config_context(**self.config):
# --> 216             return self.function(*args, **kwargs)
#     217
#     218
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     678             estimator.fit(X_train, **fit_params)
#     679         else:
# --> 680             estimator.fit(X_train, y_train, **fit_params)
#     681
#     682     except Exception:
#
# ~\anaconda3\lib\site-packages\imblearn\pipeline.py in fit(self, X, y, **fit_params)
#     295             if self._final_estimator != "passthrough":
#     296                 fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 297                 self._final_estimator.fit(Xt, yt, **fit_params_last_step)
#     298         return self
#     299
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py in fit(self, X, y, sample_weight, monitor)
#     584
#     585         # fit the boosting stages
# --> 586         n_stages = self._fit_stages(
#     587             X,
#     588             y,
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py in _fit_stages(self, X, y, raw_predictions, sample_weight, random_state, X_val, y_val, sample_weight_val, begin_at_stage, monitor)
#     661
#     662             # fit next stage of trees
# --> 663             raw_predictions = self._fit_stage(
#     664                 i,
#     665                 X,
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py in _fit_stage(self, i, X, y, raw_predictions, sample_weight, sample_mask, random_state, X_csc, X_csr)
#     244
#     245             X = X_csr if X_csr is not None else X
# --> 246             tree.fit(X, residual, sample_weight=sample_weight, check_input=False)
#     247
#     248             # update tree leaves
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1313         """
#    1314
# -> 1315         super().fit(
#    1316             X,
#    1317             y,
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     418             )
#     419
# --> 420         builder.build(self.tree_, X, y, sample_weight)
#     421
#     422         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:
